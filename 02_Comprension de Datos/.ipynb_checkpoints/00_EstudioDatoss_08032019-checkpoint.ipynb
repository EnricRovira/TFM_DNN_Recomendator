# %% [markdown]
# # EstudioDatos

# %%
import pandas as pd
from collections import Counter
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import ast

pd.set_option('max_colwidth', 250)

# %%
data = pd.read_csv('../00_Datos/Datos_Finales/126kProducts_20190309.csv', sep = ';')
data.head()
# Out:
# C:\Users\Enric\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (6,9,12,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 alternative_id  availability_date                badges  \
# 0           0      A28233506                NaN  ['express_delivery']
# 1           1      A29054782                NaN  ['express_delivery']
# 2           2      A27354432                NaN  ['express_delivery']
# 3           3      A28302706                NaN  ['express_delivery']
# 4           4      A27435502                NaN  ['express_delivery']
#
#                            brand                      category discount  \
# 0  Woman Limited El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']      NaN
# 1  Woman Limited El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']      NaN
# 2          Woman El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']      NaN
# 3                        Lloyd's  ['Moda', 'Mujer', 'Abrigos']      NaN
# 4                        Lloyd's  ['Moda', 'Mujer', 'Abrigos']      NaN
#
#   eci_provider          gtin             id  ...         media module_name  \
# 0     00000000  2.401700e+12  1060651400131  ...  {'count': 1}         NaN
# 1     00000000  2.606514e+12  1060651400180  ...  {'count': 1}         NaN
# 2     00000000  2.510564e+12  1051056400107  ...  {'count': 1}         NaN
# 3     00000000  2.401701e+12  1019350401147  ...  {'count': 1}         NaN
# 4     00000000  2.193534e+12  1019353400229  ...  {'count': 1}         NaN
#
#                                                        name position  \
# 0                     Abrigo masculino con textura de mujer      NaN
# 1             Abrigo doble faz de mujer con cinturón a tono      NaN
# 2   Abrigo largo de antelina de mujer Woman El Corte Inglés      NaN
# 3  Chaqueta térmica de mujer Lloyds con efecto cortavientos      NaN
# 4            Parka 100% algodón de mujer Lloyds con capucha      NaN
#
#                                  price quantity    status store_id  \
# 0    {'final': 199, 'currency': 'EUR'}        1  show_pdp       60
# 1    {'final': 149, 'currency': 'EUR'}        1  show_pdp       60
# 2  {'final': 89.99, 'currency': 'EUR'}        1  show_pdp       60
# 3    {'final': 129, 'currency': 'EUR'}        1  show_pdp       60
# 4    {'final': 149, 'currency': 'EUR'}        1  show_pdp       60
#
#               variant vendor
# 0  001060651400131002    NaN
# 1  001060651400180002    NaN
# 2  001051056400107002    NaN
# 3  001019350401147002    NaN
# 4  001019353400229002    NaN
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (126837, 21)

# %% [markdown]
# Borramos las columnas que sabemos que no vamos a necesitar de esta forma el DF ocupa menos y es mas facil de manejar

# %%
data = data.drop(['alternative_id', 'availability_date', 'badges',
                 'discount', 'eci_provider', 'gtin', 'media', 'module_name',
                 'position', 'quantity', 'status', 'store_id', 
                 'variant', 'vendor'], axis = 1)
data.head()
# Out:
#    Unnamed: 0                          brand                      category  \
# 0           0  Woman Limited El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']
# 1           1  Woman Limited El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']
# 2           2          Woman El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']
# 3           3                        Lloyd's  ['Moda', 'Mujer', 'Abrigos']
# 4           4                        Lloyd's  ['Moda', 'Mujer', 'Abrigos']
#
#               id  \
# 0  1060651400131
# 1  1060651400180
# 2  1051056400107
# 3  1019350401147
# 4  1019353400229
#
#                                                                                        image  \
# 0  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00160651400131____1__516x640.jpg
# 1  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/06/00160651400180____1__516x640.jpg
# 2  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00151056400115____1__516x640.jpg
# 3  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00119350401147____3__516x640.jpg
# 4  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00119353400237____2__516x640.jpg
#
#                                                        name  \
# 0                     Abrigo masculino con textura de mujer
# 1             Abrigo doble faz de mujer con cinturón a tono
# 2   Abrigo largo de antelina de mujer Woman El Corte Inglés
# 3  Chaqueta térmica de mujer Lloyds con efecto cortavientos
# 4            Parka 100% algodón de mujer Lloyds con capucha
#
#                                  price
# 0    {'final': 199, 'currency': 'EUR'}
# 1    {'final': 149, 'currency': 'EUR'}
# 2  {'final': 89.99, 'currency': 'EUR'}
# 3    {'final': 129, 'currency': 'EUR'}
# 4    {'final': 149, 'currency': 'EUR'}

# %% [markdown]
# ### Me guardo las marcas para usarlas mas adelante

# %%
data.to_csv('Marcas_20190308.csv', sep = ';',index=False, encoding = 'UTF-8')

# %% [markdown]
#  ---

# %% [markdown]
# ### Nulos?

# %%
fig = plt.figure(figsize=(10, 8))
plt.title("Distribution of NA")
data.isna().sum().sort_values(ascending=True).plot(kind='barh',colors='Blue', fontsize=12)
# Out:
# C:\Users\Enric\Anaconda3\lib\site-packages\pandas\plotting\_core.py:185: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"

# %% [markdown]
# Solo hay nulos en las marcas y unos 370 que de 88448 representa un 0.4% por tanto no es muy preocupante, además seguramente la marca la acabemos incorporando dentro del texto final por tanto en caso de que no se conoca la marca no la ánadiremos al corpus de texto de ese producto

# %% [markdown]
# ## Categoria

# %%
data_copy = data.copy()

# %%
for i, lista in enumerate(data_copy['category'].values):
    data_copy['category'].values[i] = ast.literal_eval(lista)
#for i, elem in enumerate(data_copy['category']):
#    data_copy['category'].values[i] = [x.replace(" ", "_") for x in elem ]

# %%
# Comentar para solo juntar los de cada lista
#data_copy['category'] = data_copy['category'].apply(lambda x: '_'.join(x))

# %%
data_copy['category'][19000]
# Out:
# ['Moda', 'Zapatos', 'Zapatos de mujer', 'Botas']

# %% [markdown]
# Ahora ya podemos sacar cuantas Categorias distintas hay y cuales son las que mas aparecen

# %% [markdown]
# ### Top Categorias

# %% [markdown]
# Tenemos una lista de valores en vez de tener un unico valor por tanto necesitaremos suar la libreria Counter e itertools

# %%
categories = Counter(itertools.chain.from_iterable(data_copy['category'].values))
categories.most_common()
# Out:
# [('Moda', 62902),
#  ('Infantil', 17875),
#  ('Accesorios', 10343),
#  ('Hombre', 10138),
#  ('Mujer', 8698),
#  ('Deportes', 8614),
#  ('Hogar', 8515),
#  ('Bebés', 7446),
#  ('Zapatos', 6714),
#  ('Electrónica', 6402),
#  ('Niña (1-16 años)', 5602),
#  ('Juguetes', 5378),
#  ('Lencería', 4905),
#  ('Joyería y Relojes', 4672),
#  ('Perfumería', 4526),
#  ('Bebé Niña (0-36 meses)', 4157),
#  ('Niño (1-16 años)', 3928),
#  ('Electrodomésticos', 3517),
#  ('Cine', 3396),
#  ('Accesorios de Hombre', 3276),
#  ('Zapatos de mujer', 3075),
#  ('Bebé Niño (0-36 meses)', 2965),
#  ('Libros', 2953),
#  ('Ropa deportiva', 2888),
#  ('Música', 2684),
#  ('Camisetas y Polos', 2097),
#  ('Abrigos', 2077),
#  ('Regalos originales', 2030),
#  ('Vestidos', 1916),
#  ('Maquillaje', 1840),
#  ('Bolsos', 1815),
#  ('Camisetas', 1781),
#  ('Camisas', 1720),
#  ('Punto y Jerseys', 1664),
#  ('Papelería', 1619),
#  ('Pantalones', 1617),
#  ('Menaje de mesa', 1600),
#  ('Jerseys y Chaquetas', 1576),
#  ('Videojuegos', 1561),
#  ('Joyería Mujer', 1481),
#  ('BriCor', 1478),
#  ('Zapatos de hombre', 1442),
#  ('Bisutería', 1336),
#  ('Ropa de cama', 1266),
#  ('Equipaje', 1237),
#  ('Calcetines', 1192),
#  ('Bragas', 1161),
#  ('Perfumería General', 1152),
#  ('Muñecas y peluches', 1097),
#  ('Muebles', 1093),
#  ('Camisas, Blusas y Tops', 1079),
#  ('Rostro Mujer', 1068),
#  ('Baño', 1063),
#  ('Relojes Hombre', 1024),
#  ('Decoración', 1013),
#  ('Mascotas', 1012),
#  ('Sujetadores', 1001),
#  ('Hidratantes', 986),
#  ('Zapatillas', 980),
#  ('Vaqueros', 971),
#  ('Pulseras', 963),
#  ('Menaje de cocina', 960),
#  ('Sonido', 955),
#  ('Juegos', 932),
#  ('Pantalones y Leggins', 911),
#  ('Fragancias', 890),
#  ('Relojes Mujer', 885),
#  ('Muñecos articulados', 877),
#  ('Hornos, Placas y Campanas', 873),
#  ('Complementos', 811),
#  ('Pendientes', 809),
#  ('Gafas de sol', 786),
#  ('Carteras y Monederos', 780),
#  ('Carteras', 777),
#  ('Accesorios de paseo', 752),
#  ('Blusas y Camisas', 751),
#  ('Cunas', 747),
#  ('Accesorios Móviles', 746),
#  ('Calcetines y Leotardos', 737),
#  ('Ropa Interior', 736),
#  ('Preescolar', 733),
#  ('Mochilas', 708),
#  ('Fútbol', 703),
#  ('Parafarmacia', 696),
#  ('Cazadoras', 695),
#  ('Niños', 692),
#  ('Cómics', 676),
#  ('Frigoríficos y Congeladores', 675),
#  ('Zapatos de niña', 672),
#  ('Faldas', 665),
#  ('Maletas', 654),
#  ('Cinturones', 631),
#  ('Rostro', 604),
#  ('Deportes acuáticos', 603),
#  ('Polos', 596),
#  ('Ojos', 591),
#  ('Medias y Panties', 589),
#  ('Pijamas y Bodys', 585),
#  ('Ciclismo', 583),
#  ('Accesorios Informática', 579),
#  ('Pijamas', 577),
#  ('Calzado', 573),
#  ('Sillas de coche', 573),
#  ('Carros de bebé', 572),
#  ('Sillas de paseo', 559),
#  ('Fragancias Mujer', 556),
#  ('Pantalones y Bermudas', 553),
#  ('Gorros y Sombreros', 545),
#  ('Camisetas interiores', 541),
#  ('Labios', 541),
#  ('Petos y Ranitas', 536),
#  ('Figuras y mascotas', 520),
#  ('Zapatillas deportivas', 506),
#  ('Bicicletas', 506),
#  ('Camisones', 480),
#  ('Eau de Toilette', 477),
#  ('Zapatos de cordones y bluchers', 471),
#  ('Botas y Zapatillas', 466),
#  ('Collares', 463),
#  ('Running', 461),
#  ('Anillos', 458),
#  ('Bolsos y neceseres', 456),
#  ('Bandoleras', 455),
#  ('Fragancias Hombre', 454),
#  ('Sudaderas', 452),
#  ('Primera Infancia', 450),
#  ('Pañuelos y Fulares', 448),
#  ('Antiedad', 441),
#  ('Ropa', 434),
#  ('Bailarinas y slippers', 428),
#  ('Novela romántica', 427),
#  ('Textil baño', 423),
#  ('Fundas y carcasas', 422),
#  ('Ordenadores', 415),
#  ('Textil decoración', 415),
#  ('Reacondicionados', 414),
#  ('Mini muñecas y playsets', 413),
#  ('Sandalias', 412),
#  ('Zapatos de niño', 409),
#  ('Sofás', 407),
#  ('Novela histórica', 406),
#  ('Montaña', 405),
#  ('Ropa de Baño', 402),
#  ('Cojines', 400),
#  ('Corbatas', 399),
#  ('Impresoras', 399),
#  ('Disfraces y complementos', 398),
#  ('Mujer Tallas Grandes', 392),
#  ('Bolsos de hombro', 392),
#  ('Autoayuda', 392),
#  ('Auriculares', 388),
#  ('Juegos de mesa', 386),
#  ('Libros de Texto', 384),
#  ('Clásico', 384),
#  ('Soul-Funk-R&B', 384),
#  ('Rap y Hip hop', 382),
#  ('Eau de Parfum', 380),
#  ('Jardín', 380),
#  ('Menaje Infantil', 376),
#  ('Chaquetas y Blazers', 374),
#  ('Botines', 372),
#  ('Textil mesa y cocina', 370),
#  ('Zapatos de salón', 369),
#  ('Sudaderas y Chándals', 368),
#  ('Zapatillas y Botas', 365),
#  ('Fitness', 362),
#  ('Juegos educativos', 361),
#  ('Iluminación', 358),
#  ('Papeles pintados', 357),
#  ('Playsets y accesorios', 357),
#  ('Botas', 355),
#  ('Construcciones y puzzles', 355),
#  ('Preparación de alimentos', 354),
#  ('Botas y botines', 351),
#  ('Cuerpo Mujer', 350),
#  ('Coches, circuitos y radiocontrol', 348),
#  ('Bañadores', 346),
#  ('Cafeteras', 342),
#  ('Velas y aromas', 341),
#  ('Sábanas', 341),
#  ('Joyería Infantil', 340),
#  ('Tarjetas de memoria y Pen drives', 340),
#  ('Lavadoras', 339),
#  ('Pádel', 339),
#  ('Antiarrugas', 339),
#  ('Para preparar', 338),
#  ('Ordenación', 338),
#  ('Móviles y Smartphones', 337),
#  ('Barras de Labios', 337),
#  ('Altavoces portátiles', 336),
#  ('Esquí y Snow', 333),
#  ('Nintendo Switch', 332),
#  ('Accesorios para sillas de coche', 332),
#  ('Estuches y Neceseres', 331),
#  ('Colgantes', 331),
#  ('Accesorios Fotografía', 330),
#  ('Hornos de cocina', 328),
#  ('Hombre Tallas Grandes', 327),
#  ('Pijamas y Homewear', 324),
#  ('Instrumentos musicales', 320),
#  ('PC', 320),
#  ('Protectores de pantalla', 319),
#  ('Copas', 319),
#  ('Piscinas', 318),
#  ('Objetivos', 317),
#  ('Fiesta Hombre', 316),
#  ('Cajas regalo', 316),
#  ('Accesorios para el pelo', 314),
#  ('Monitores PC', 314),
#  ('Discos Duros', 314),
#  ('Jugar a ser mayor', 314),
#  ('TeenStore', 312),
#  ('Mercería', 312),
#  ('Xbox One', 311),
#  ('Mocasines y Drivers', 310),
#  ('Charms', 310),
#  ('PS4', 310),
#  ('Vasos', 309),
#  ('Platos', 307),
#  ('Peluches', 306),
#  ('Café y té', 305),
#  ('Bolsos de mano', 300),
#  ('Sujetadores con aro', 298),
#  ('Artístico', 298),
#  ('Zapatos confort', 293),
#  ('Ligeras', 293),
#  ('Ensamblaje', 289),
#  ('Fundas', 287),
#  ('2 piezas', 285),
#  ('Golf', 281),
#  ('Figuras y Vehículos', 276),
#  ('Conjuntos', 272),
#  ('STAR WARS', 272),
#  ('Frigoríficos combi', 270),
#  ('Figuras', 267),
#  ('Tratamiento Facial', 267),
#  ('Minicunas', 266),
#  ('Fiesta Mujer', 265),
#  ('Tarjeteros', 264),
#  ('Accesorios para perros', 264),
#  ('Bandoleras y riñoneras', 263),
#  ('Escritorio y Papelería', 262),
#  ('Habilidad', 260),
#  ('Básicos Mujer', 256),
#  ('Campanas extractoras de cocina', 256),
#  ('Placas de cocina', 256),
#  ('Lavadora de carga frontal', 255),
#  ('Todo Recibidor', 255),
#  ('Maletas Cabina', 253),
#  ('Accesorios para playa', 251),
#  ('Toallas', 249),
#  ('Maletas Grandes', 247),
#  ('Altavoces Bluetooth', 243),
#  ('Modulares', 242),
#  ('Cabello', 238),
#  ('Camisetas interiores básicas', 236),
#  ('Portatiles', 235),
#  ('Novela - Narrativa', 234),
#  ('Accesorios de invierno', 232),
#  ('Sacos', 230),
#  ('Comida para gatos', 230),
#  ('Sillas', 228),
#  ('Cartuchos de tinta', 226),
#  ('Menaje y decoración', 225),
#  ('Infantiles y juveniles', 225),
#  ('Moda y complementos', 223),
#  ('Fundas nórdicas', 221),
#  ('Terraza y Jardín', 220),
#  ('Bikinis', 219),
#  ('Especial Regalos para el bebé', 219),
#  ('Tronas', 217),
#  ('Mesas', 216),
#  ('Camping y Playa', 215),
#  ('Accesorios de Baño', 214),
#  ('TV', 213),
#  ('Aspiración y limpieza', 213),
#  ('Superhéroes', 213),
#  ('Lavavajillas', 211),
#  ('Cuidados Capilares', 211),
#  ('Escritura y Corrección', 211),
#  ('Novela negra y Policíaca', 209),
#  ('Agendas y Calendarios', 209),
#  ('Cuadernos, Libretas y Recambios', 209),
#  ('Tratamientos Solares', 208),
#  ('Toalla de baño', 207),
#  ('Electrónicos', 207),
#  ('Packs de regalo', 207),
#  ('Cuidados Cuerpo', 206),
#  ('Muñecas modelo', 205),
#  ('Tecnología', 205),
#  ('Archivo y Clasificación', 205),
#  ('Cuidados Rostro', 204),
#  ('Manga', 204),
#  ('Sofás tapizados', 202),
#  ('Accesorios para vino', 202),
#  ('Colchones y almohadas', 202),
#  ('Salud, bienestar y dietas', 202),
#  ('Cocina', 201),
#  ('Material de Escritorio', 200),
#  ('Mochilas y carros', 200),
#  ('Relojes Infantiles', 199),
#  ('Preparación repostería', 199),
#  ('Escritura de Lujo', 199),
#  ('Mini Home - El Corte Inglés', 198),
#  ('Juguetes al aire libre', 198),
#  ('Regalos frikis', 198),
#  ('Drama', 198),
#  ('Pantalones cortos y Bermudas', 197),
#  ('Cuchillos de cocina', 197),
#  ('Clásicos del Cómic', 196),
#  ('Paraguas', 195),
#  ('Muebles de baño', 195),
#  ('Higiene para perros', 194),
#  ('Objetivos Réflex', 193),
#  ('Lecturas Recomendadas', 193),
#  ('Tratamientos Ojos', 192),
#  ('Patinaje', 192),
#  ('Ortopedia y dependencia', 192),
#  ('CHANEL', 192),
#  ('Acción y Aventuras', 192),
#  ('Bélico', 192),
#  ('Comedia', 192),
#  ('Documental', 192),
#  ('Musical', 192),
#  ('Series de Tv', 192),
#  ('Country', 192),
#  ('Country - Western - Bluegrass - Tex-Mex', 192),
#  ('Dance y Electrónica', 192),
#  ('Flamenco y Canción Española', 192),
#  ('Hard Rock y Metal', 192),
#  ('Canciones Infantiles', 192),
#  ('Jazz-Blues', 192),
#  ('Música Regional', 192),
#  ('Músicas del Mundo y New Age', 192),
#  ('Pop-Rock', 192),
#  ('Ferretería', 192),
#  ('Perfiles', 192),
#  ('Cocinas', 192),
#  ('Puertas y ventanas', 192),
#  ('Terror', 191),
#  ('Western', 191),
#  ('Bandas Sonoras', 191),
#  ('Ratones', 190),
#  ('Español', 190),
#  ('Reggae', 190),
#  ('Look Oficina', 189),
#  ('Peletería', 189),
#  ('Digital Sony Playstation', 189),
#  ('Intriga y Suspense', 189),
#  ('Juegos de entretenimiento', 188),
#  ('Riego', 188),
#  ('Higiene y cuidado del bebé', 187),
#  ('Animación', 187),
#  ('Portadocumentos y maletines', 185),
#  ('Otros accesorios', 184),
#  ('Reggae - Ska - Dub - Dancehall', 184),
#  ('Jazz', 183),
#  ('Muebles de Jardín', 183),
#  ('Aire acondicionado', 182),
#  ('Accesorios de fiesta', 181),
#  ('Split', 181),
#  ('Romántico', 180),
#  ('Tratamiento Corporal', 179),
#  ('Fantástico y ciencia ficción', 179),
#  ('Accesorios para gatos', 176),
#  ('Capazos', 174),
#  ('Baño y Playa', 173),
#  ('Portátiles convencionales', 173),
#  ('Chanclas de baño', 171),
#  ('Pijamas completos', 168),
#  ('Bolsas de viaje', 168),
#  ('Placas de inducción', 168),
#  ('Anime', 168),
#  ('Hornos multifunción', 167),
#  ('Campanas decorativas', 166),
#  ('TV LED', 164),
#  ('Juego de sábanas', 163),
#  ('Limpiadoras', 163),
#  ('Carpetas', 162),
#  ('Electrónica deportiva', 160),
#  ('Sombras de Ojos', 160),
#  ('Delineadores', 159),
#  ('Lavavajillas 60 cm', 157),
#  ('Americanas y Blazers', 156),
#  ('Sujetadores sin aro', 156),
#  ('TV y Sonido', 156),
#  ('Minicunas - Moisés', 156),
#  ('Higiene Corporal', 154),
#  ('Comida húmeda', 153),
#  ('Nuestro mejor precio el corte ingles', 150),
#  ('Champús', 149),
#  ('Viajes', 149),
#  ('Trajes', 148),
#  ('Bicicletas Montaña MTB', 146),
#  ('Bases de Maquillaje', 146),
#  ('Comuniones', 144),
#  ('Bandas sonoras de películas', 143),
#  ('Estuches de Regalo', 142),
#  ('Pienso', 141),
#  ('Comida para perros', 141),
#  ('Tenis', 139),
#  ('Agendas Anuales', 139),
#  ('Mocasines y Náuticos', 138),
#  ('Juego de funda nórdica', 138),
#  ('Cuerpo', 138),
#  ('Protección', 137),
#  ('Otros Mangas', 137),
#  ('Flamenco', 137),
#  ('Shorts y Bermudas', 136),
#  ('Aromas', 136),
#  ('Camisetas interiores con detalles', 133),
#  ('Auriculares Diadema', 133),
#  ('9 Meses a 12 Años: Grupo 1-2-3', 132),
#  ('Split 1 x 1', 131),
#  ('Zapatos de confort', 130),
#  ('Auriculares de botón', 130),
#  ('3-12 Años: Grupo 2-3', 130),
#  ('DIOR', 130),
#  ('House - Techno - Dance', 130),
#  ('Disfraz Infantil', 129),
#  ('Lifting', 128),
#  ('Accesorios de fijar', 128),
#  ('Sillas i-Size', 127),
#  ('Monederos', 125),
#  ('Panties', 124),
#  ('Packs', 123),
#  ('Tratamiento', 118),
#  ('Bicicletas Eléctricas', 116),
#  ('Desodorantes', 115),
#  ('Bicicletas Carretera', 115),
#  ('Mantenimiento', 115),
#  ('Diseño', 115),
#  ('Congeladores', 114),
#  ('Casual - Sneakers', 114),
#  ('Coches', 112),
#  ('Gastronomía', 112),
#  ('Camisetas de pijama', 111),
#  ('Accesorios de cocina sobreponer', 110),
#  ('Tops de Bikini', 109),
#  ('Objetivos Evil', 109),
#  ('Lego', 109),
#  ('Ordenadores y accesorios', 108),
#  ('Gorros y Gorras', 107),
#  ('Muebles Auxiliares', 107),
#  ('Muebles de baño suspendidos', 106),
#  ('Muñecas bebé', 106),
#  ('3 piezas', 106),
#  ('Sephora', 106),
#  ('TV y Vídeo', 104),
#  ('Radiocontrol', 104),
#  ('Termos y bolsas térmicas', 104),
#  ('Hard Rock - Metal Internacional', 104),
#  ('9-36 Meses: Grupo 1', 102),
#  ('Colchonetas y tapizados', 102),
#  ('Novela Española e Hispanoamericana', 102),
#  ('Tangas', 101),
#  ('Velas', 101),
#  ('Estrategia', 101),
#  ('Tecnobelleza', 101),
#  ('Bragas de bikini', 100),
#  ('Dibuja y pinta', 100),
#  ('Pantalones de pijama', 99),
#  ('Vasos, tazas y botellas', 99),
#  ('Moldes', 98),
#  ('Cuadernos', 98),
#  ('Contenido Adicional', 97),
#  ('Novela Extranjera', 96),
#  ('Puertas Interiores Sintéticas', 94),
#  ('Accesorios Maquillaje', 93),
#  ('Brillos de Labios', 92),
#  ('Telefonía', 91),
#  ('Samsung', 91),
#  ('Gorras', 90),
#  ('Circuitos Parkings Accesorios', 89),
#  ('Máscara de Pestañas', 89),
#  ('Neceseres', 88),
#  ('Frigoríficos 1 puerta', 88),
#  ('Afeitado', 88),
#  ('Tazas', 88),
#  ('Limpieza', 87),
#  ('Manteles', 87),
#  ('Cojines decorativos', 87),
#  ('Menaje de exterior', 86),
#  ('Sinfónico por Compositores', 86),
#  ('Recambios', 85),
#  ('Capotas y mosquiteras', 85),
#  ('Accesorios de Escritorio', 85),
#  ('Champús, colonias y toallitas', 85),
#  ('Formal', 84),
#  ('Mochilas Portabebés', 84),
#  ('Correctores', 84),
#  ('Mochilas Casual', 84),
#  ('Pendrives', 83),
#  ('Mandos de control', 82),
#  ('0-18 Meses: Grupo 0-0+', 82),
#  ('Mascarillas', 82),
#  ('Pop - Rock Internacional', 82),
#  ('Puertas Melamina', 82),
#  ('Basicos Hombre', 81),
#  ('Platos y vajillas', 81),
#  ('Higiene', 81),
#  ('Frigoríficos 2 puertas', 79),
#  ('Muñecos', 79),
#  ('Sillas de comedor', 78),
#  ('Música Regional Cataluña', 78),
#  ('iPad y Tablet', 77),
#  ('Juegos de exterior', 77),
#  ('eBooks', 77),
#  ('Pinkies', 76),
#  ('Maletas Medianas', 76),
#  ('Robots', 76),
#  ('Accesorios para tronas', 76),
#  ('Platos llanos', 75),
#  ('Platos de postre', 75),
#  ('Sillas y mesas Gaming', 75),
#  ('Pop - Rock Español y Latino', 75),
#  ('Fundas, Bolsas, Mochilas y Correas', 73),
#  ('Led', 73),
#  ('Moldea', 72),
#  ('Multiexperiencias', 72),
#  ('Bolígrafos de Lujo', 72),
#  ('Auriculares Deportivos', 71),
#  ('Taco', 71),
#  ('Sábanas encimeras', 71),
#  ('Albornoces', 71),
#  ('Gaming', 70),
#  ('Sofás modulares', 70),
#  ('Toallas de playa', 70),
#  ('Teclados', 69),
#  ('Perchas de baño', 69),
#  ('Muebles de recibidor', 69),
#  ('Brochas', 69),
#  ('Paseo', 69),
#  ('Tarjetas de memoria', 68),
#  ('Fotografía', 68),
#  ('Equipaciones Oficiales', 68),
#  ('Geles de Baño', 68),
#  ('Decoración para fiestas', 67),
#  ('Móviles y smartphones libres', 66),
#  ('Sábanas bajeras', 65),
#  ('Mugs', 65),
#  ('Lociones Corporales', 65),
#  ('Nutrición y Dietas', 65),
#  ('Bolsos de fiesta', 64),
#  ('Mesas auxiliares', 64),
#  ('Platos hondos', 64),
#  ('Bolsos, mochilas y trolleys', 64),
#  ('Otros muebles y accesorios', 64),
#  ('Rotuladores', 64),
#  ('Caprichos', 63),
#  ('Racores automáticos y accesorios', 63),
#  ('Batas', 62),
#  ('Carteras de mano', 62),
#  ('Secadoras', 62),
#  ('Perfiladores', 62),
#  ('Preparadores y Fijadores', 62),
#  ('Cejas', 62),
#  ('Electrónica - Ambient - Chill Out', 62),
#  ('Colecciones de aromas para el hogar', 61),
#  ('Bolsas y fundas', 61),
#  ('Internacional', 61),
#  ('Collares y colgantes', 60),
#  ('Secadoras de condensación', 60),
#  ('Baberos', 60),
#  ('Llaveros', 59),
#  ('Copas de vino', 59),
#  ('Acondicionadores', 59),
#  ('Menaje y Hogar', 59),
#  ('Flash y Luz', 58),
#  ('Chaquetas', 58),
#  ('Sillas de escritorio', 58),
#  ('Funda de cojín', 58),
#  ('Cambiadores', 58),
#  ('FEMENINOS', 58),
#  ('Ropa Deportiva', 57),
#  ('Hornos compactos', 57),
#  ('Fotomurales', 57),
#  ('Lámparas de techo', 57),
#  ('Cuidado Facial y Corporal', 57),
#  ('Baño y Cuerpo', 57),
#  ('Fundas para iPad', 56),
#  ('Frigoríficos Side by Side', 56),
#  ('GPS', 56),
#  ('Hidratación Intensiva', 56),
#  ('Bolígrafos y Roller', 56),
#  ('Aventuras', 56),
#  ('Monos', 55),
#  ('Trajes, americanas y pantalones', 55),
#  ('Portátiles Convertibles 2 en 1', 55),
#  ('Sobremesa', 55),
#  ('Radios', 55),
#  ('Smartwatches', 55),
#  ('Delantales', 55),
#  ('Juegos de copas de vino', 55),
#  ('Hamacas', 55),
#  ('Agendas Encuadernadas', 55),
#  ('iPad', 54),
#  ('Afeitadoras', 54),
#  ('Bolsas y Ojeras', 54),
#  ('Primero Primaria', 54),
#  ('Muebles auxiliares de baño', 53),
#  ('Seguridad en casa', 53),
#  ('Accesorios de chupetes', 53),
#  ('Juguetes y entretenimiento', 53),
#  ('Chalecos', 52),
#  ('Multifunciones tinta', 52),
#  ('Camas', 52),
#  ('Funda nórdica pieza suelta', 52),
#  ('Albornoz de baño', 52),
#  ('Molinillos', 52),
#  ('Barbacoas', 52),
#  ('Adaptadores', 52),
#  ('Tóner', 51),
#  ('Mesas de centro', 51),
#  ('Más complemetos', 51),
#  ('Polvos', 51),
#  ('Coloretes', 51),
#  ('Bodys', 50),
#  ('Microondas', 50),
#  ('Bicicletas Urbanas - Trekking', 50),
#  ('Paños de cocina', 50),
#  ('Cubiertos', 50),
#  ('Tazas de té', 50),
#  ('Puzzles', 50),
#  ('Bolsos de maternidad', 50),
#  ('Sérums', 50),
#  ('Split 2 x 1', 50),
#  ('Viaje', 50),
#  ('Carpetas de Anillas', 50),
#  ('Culottes', 49),
#  ('Riñoneras', 49),
#  ('Leggins', 49),
#  ('Placas vitrocerámicas', 49),
#  ('Marcos de fotos', 49),
#  ('Smartphones y tablets', 49),
#  ('Zapatillas de casa', 48),
#  ('Coctel', 48),
#  ('Gorros', 48),
#  ('Cazadoras y Americanas', 48),
#  ('Planchado y costura', 48),
#  ('Para tu casita', 48),
#  ('Bases', 47),
#  ('Edredones', 47),
#  ('Servilletas', 47),
#  ('Juego de servilletas', 47),
#  ('Juegos electrónicos', 47),
#  ('Accesorios biberones', 47),
#  ('Bautizo', 47),
#  ('Perfumes de Autor', 47),
#  ('Juegos Completos', 47),
#  ('Reparador', 47),
#  ('Jabones', 47),
#  ('Cocina Práctica', 47),
#  ('Comederos y bebederos', 47),
#  ('Muebles de Baño', 47),
#  ('Camisas, blusas y tops', 46),
#  ('Sujetadores push up', 46),
#  ('Campanas telescópicas', 46),
#  ('Sillas de cocina', 46),
#  ('Sofás de 3 plazas', 46),
#  ('Juegos deportivos', 46),
#  ('Accesorios muñecas bebé', 46),
#  ('Novelas gráficas y Cómics de Autor', 46),
#  ('Bralettes', 45),
#  ('Discos duros externos', 45),
#  ('Candelabros y portavelas', 45),
#  ('Biberones', 45),
#  ('Iluminadores', 45),
#  ('Embarazo y Parto', 45),
#  ('Blocs y Libretas', 45),
#  ('Etiqueta', 44),
#  ('Sombreros', 44),
#  ('Bolsas deporte', 44),
#  ('Manteles individuales', 44),
#  ('Sacacorchos', 44),
#  ('Limpieza Rostro', 44),
#  ('Carpetas con Gomas', 44),
#  ('Herramienta manual de jardín', 44),
#  ('Microaspersión y gota a gota', 44),
#  ('Sujetadores deportivos', 43),
#  ('Pelotas', 43),
#  ('Otros vehículos', 43),
#  ('Nutrición general', 43),
#  ('Soportes altavoces', 42),
#  ('Lavadora-Secadora', 42),
#  ('Lavavajillas 45 cm', 42),
#  ('Mantas, sábanas y toquillas', 42),
#  ('Cuidado Manos', 42),
#  ('Autobronceadores', 42),
#  ('Infantil 3-6 años - VISUALES y DIDACTICOS', 42),
#  ('Vestidos de playa', 41),
#  ('Relojes inteligentes', 41),
#  ('Cafeteras de cápsulas', 41),
#  ('Bicicletas Niños', 41),
#  ('Mantas', 41),
#  ('Cuadrantes', 41),
#  ('Accesorios habitación', 41),
#  ('Anticelulíticos', 41),
#  ('Abrigos y Cazadoras', 40),
#  ('Filtros, Tapas y Parasoles', 40),
#  ('Juegos de vasos', 40),
#  ('Mesas de jardín', 40),
#  ('Colchonetas', 40),
#  ('Sillones de lactancia', 40),
#  ('Fundas móviles', 40),
#  ('Mochilas Adulto', 40),
#  ('Agendas de Espiral', 40),
#  ('Series', 40),
#  ('Lencería Sexy', 39),
#  ('Cortinas', 39),
#  ('Manteles resinados', 39),
#  ('Mascotas interactivas', 39),
#  ('Accesorios muñecas modelo', 39),
#  ('Peines y Cepillos', 39),
#  ('Shonen', 39),
#  ('Conexiones y enlaces', 39),
#  ('Tocados', 38),
#  ('Vajillas', 38),
#  ('Auriculares y altavoces', 38),
#  ('Nuestras Marcas Juguetes', 38),
#  ('Sombrillas', 38),
#  ('Accesorios Ojos', 38),
#  ('Desmaquillantes Rostro', 38),
#  ('Uñas', 38),
#  ('Dulces y Postres', 38),
#  ('Música Regional Galicia', 38),
#  ('Ropa interior', 37),
#  ('Maletines y mochilas para portátil', 37),
#  ('Radios portátiles', 37),
#  ('Cortapelos', 37),
#  ('Placas modulares', 37),
#  ('Sala', 37),
#  ('Accesorios de fitness', 37),
#  ('Lámparas de mesa', 37),
#  ('Científico', 37),
#  ('Otros', 37),
#  ('Tierras, Abonos y Fitosanitarios', 37),
#  ('Puertas Interiores Lacado Blanco', 37),
#  ('Bufandas', 36),
#  ('Fundas para tablet', 36),
#  ('iPad Pro', 36),
#  ('Calcetines, Medias y Pantorrilleras', 36),
#  ('Infantil y Juvenil', 36),
#  ('Muebles de baño con patas', 36),
#  ('Lámparas para recibidor', 36),
#  ('Nintendo 2DS 3DS', 36),
#  ('Ver Todo Maquillaje', 36),
#  ('Mochilas Infantil', 36),
#  ('Pegamentos y Cintas adhesivas', 36),
#  ('Puertas lacadas en blanco', 36),
#  ('Medias', 35),
#  ('Discos duros portátiles', 35),
#  ('Reproductores de música', 35),
#  ('MP3 y MP4', 35),
#  ('Camas nido', 35),
#  ('Agarradores', 35),
#  ('Cuchillos universales', 35),
#  ('Volantes', 35),
#  ('Máscaras', 35),
#  ('Pistolas y lanzadores', 35),
#  ('Doudou', 35),
#  ('Protector de lluvia y sol', 35),
#  ('Bálsamos y Preparadores', 35),
#  ('Fijadores y Styling', 35),
#  ('Perfumes Femeninos', 35),
#  ('Clásico - Varios', 35),
#  ('Hornos de vapor', 34),
#  ('Mesas de comedor', 34),
#  ('Jarrones', 34),
#  ('Figuras decorativas', 34),
#  ('Florales', 34),
#  ('Colchas', 34),
#  ('Maquillaje y accesorios', 34),
#  ('Season Pass', 34),
#  ('Unisex', 34),
#  ('Spa Bienestar', 34),
#  ('Bandas sonoras de TV', 34),
#  ('Melódicos, Cantautores, Boleros Españoles y Latinos', 34),
#  ('Lencería de Novias', 33),
#  ('Smartwatch', 33),
#  ('Lavadora de carga superior', 33),
#  ('Cápsulas de café', 33),
#  ('Cojines infantiles', 33),
#  ('Portarrollos', 33),
#  ('Tablas de cortar', 33),
#  ('Luces quitamiedos', 33),
#  ('Ropa y complementos', 33),
#  ('Cremas Cuerpo', 33),
#  ('Carpetas con Recambio', 33),
#  ('Relojes', 32),
#  ('TV OLED', 32),
#  ('Baloncesto', 32),
#  ('Accesorios de baño', 32),
#  ('Organización de cocina', 32),
#  ('Figuras y Merchandising', 32),
#  ('Accesorios cunas y minicunas', 32),
#  ('Tónicos', 32),
#  ('Calendarios', 32),
#  ('Huesos', 32),
#  ('Semillas y Huertos Urbanos', 32),
#  ('Equipaciones', 31),
#  ('Organizadores', 31),
#  ('Disfraz Adulto', 31),
#  ('Chupetes', 31),
#  ('Reductores', 31),
#  ('Cuidados del Cabello', 31),
#  ('Tratamiento Manos', 31),
#  ('Rotuladores Permanentes Punta Redonda', 31),
#  ('Libros en Blanco', 31),
#  ('Rumbas y Sevillanas', 31),
#  ('Guitarra eléctrica', 30),
#  ('Trípodes y Rótulas', 30),
#  ('Cámaras de fotos', 30),
#  ('Sábanas infantiles', 30),
#  ('Caminos de mesa', 30),
#  ('Para almacenar', 30),
#  ('Porta alimentos', 30),
#  ('Primeras Arrugas', 30),
#  ('Máscaras de Pestañas', 30),
#  ('Agendas de Anillas', 30),
#  ('Huesos y snacks', 30),
#  ('Accesorios de viaje', 29),
#  ('Pro Audio, Live Sound & DJ', 29),
#  ('Cámaras compactas', 29),
#  ('Raquetas', 29),
#  ('Mesas de cocina', 29),
#  ('Pufs', 29),
#  ('Geométrico', 29),
#  ('Alfombras', 29),
#  ('Ralladores', 29),
#  ('Lámparas de diseño', 29),
#  ('Perchas', 29),
#  ('Tumbonas', 29),
#  ('Rostro Hombre', 29),
#  ('Después del Sol', 29),
#  ('Más regalos frikis', 29),
#  ('Accesorios de colgar', 29),
#  ('Sujetadores reductores', 28),
#  ('Sofás rinconeras', 28),
#  ('Sillones de jardín', 28),
#  ('Snacks', 28),
#  ('MASCULINOS', 28),
#  ('Tercero Primaria', 28),
#  ('Plumas de Lujo', 28),
#  ('Puertas de Entrada', 28),
#  ('Caftanes', 27),
#  ('Gemelos', 27),
#  ('Sujetadores con relleno', 27),
#  ('Shorts', 27),
#  ('All in One', 27),
#  ('Aspiradoras de escoba', 27),
#  ('Bicicletas elípticas', 27),
#  ('Estanterías', 27),
#  ('Sofás de 2 plazas', 27),
#  ('Bombas de vacío y tapones', 27),
#  ('Juegos 2DS 3DS', 27),
#  ('Kit de accesorios', 27),
#  ('Laboratorio de juegos', 27),
#  ('Bañeras de bebé', 27),
#  ('Minicunas de colecho', 27),
#  ('Reposacabezas y reposapiés', 27),
#  ('Aventura', 27),
#  ('Literatura', 27),
#  ('Reglas', 27),
#  ('Roller de Lujo', 27),
#  ('Acción', 27),
#  ('Hard Rock - Metal Español y Latino', 27),
#  ('Música Popular Europa', 27),
#  ('Transportines y trolleys', 27),
#  ('Guitarra clásica y acústica', 26),
#  ('Microscopios y Lupas', 26),
#  ('Pulseras de actividad', 26),
#  ('Tostadoras', 26),
#  ('Real Madrid', 26),
#  ('Mesitas de noche', 26),
#  ('Mesas auxiliares de jardín', 26),
#  ('Disfraz bebé', 26),
#  ('Aprendizaje', 26),
#  ('Películas', 26),
#  ('Cabello Mujer', 26),
#  ('Tratamientos Específicos', 26),
#  ('Caída', 26),
#  ('Música Popular América', 26),
#  ('Brasil - Bossa - Samba', 26),
#  ('Correas', 26),
#  ('Limpieza del hogar', 26),
#  ('Espejos de Baño', 26),
#  ('Bisutería de fiesta', 25),
#  ('Minimedias', 25),
#  ('Peladores', 25),
#  ('Monitores HDMI', 25),
#  ('Piano digital', 25),
#  ('Consolas', 25),
#  ('Depiladoras', 25),
#  ('Frigoríficos minis', 25),
#  ('Polares y Softshells', 25),
#  ('Chaise longue', 25),
#  ('Mantas decorativas', 25),
#  ('Juegos de copas de champán y cava', 25),
#  ('Tazas de café', 25),
#  ('Para la casa', 25),
#  ('Cunas de viaje', 25),
#  ('Portadocumentos bebés', 25),
#  ('Polvos Bronceadores', 25),
#  ('Cuidados Específicos', 25),
#  ('Pies', 25),
#  ('Medicina Natural', 25),
#  ('Rascadores', 25),
#  ('Pajaritas', 24),
#  ('Esencia Natural', 24),
#  ('Bufandas y Cuellos', 24),
#  ('Camisetas térmicas', 24),
#  ('Lencería Invisible', 24),
#  ('Cámaras Evil', 24),
#  ('Planchas de vapor', 24),
#  ('Batidoras de vaso', 24),
#  ('Armarios roperos', 24),
#  ('Espejos de pared', 24),
#  ('Cuchillos verduleros', 24),
#  ('Cuchillos peladores', 24),
#  ('Flexos LED', 24),
#  ('Cultural', 24),
#  ('Tronas de viaje', 24),
#  ('BB y CC Cream', 24),
#  ('Aceites Hidratantes', 24),
#  ('Exfoliantes', 24),
#  ('Juegos de rol', 24),
#  ('Tableros', 24),
#  ('Quinto Primaria', 24),
#  ('Cocina Española', 24),
#  ('Bolígrafos Tinta Base Aceite', 24),
#  ('Ópera por Compositor', 24),
#  ('Canción Española y Pasodobles', 24),
#  ('Más accesorios', 23),
#  ('Merceditas', 23),
#  ('Cadenas', 23),
#  ('Cubrepañales', 23),
#  ('Altavoces Multiroom', 23),
#  ('Cables', 23),
#  ('Cargadores', 23),
#  ('Tablet', 23),
#  ('Afeitadoras faciales', 23),
#  ('Campanas isla', 23),
#  ('Hidratación', 23),
#  ('Palas', 23),
#  ('NBA', 23),
#  ('Ingredientes', 23),
#  ('Copas de cocktails y licores', 23),
#  ('Pantallas', 23),
#  ('Con pantalla', 23),
#  ('Sillas de jardín', 23),
#  ('Toalleros', 23),
#  ('Espejos de baño de aumento', 23),
#  ('Patinetes', 23),
#  ('Fundas de chupete', 23),
#  ('Reafirmantes', 23),
#  ('Preparación Afeitado', 23),
#  ('Juegos de cartas', 23),
#  ('Infantil 0-3 años - INTERACTIVOS', 23),
#  ('Medallas', 22),
#  ('Sujetadores de lactancia', 22),
#  ('Monos y Petos', 22),
#  ('Carcasas y Soportes', 22),
#  ('Prismáticos', 22),
#  ('Taco-Turf', 22),
#  ('Armarios juveniles e infantiles', 22),
#  ('Para cocinar', 22),
#  ('Copas de champán y cava', 22),
#  ('Flores y plantas artificiales', 22),
#  ('Explorer', 22),
#  ('Tetinas', 22),
#  ('Orinales', 22),
#  ('Gemelares', 22),
#  ('Limpieza Facial', 22),
#  ('Salud', 22),
#  ('Coloración', 22),
#  ('Solares', 22),
#  ('Infantil 6-9 años - LECTURAS', 22),
#  ('Infantil 6 a 9 años', 22),
#  ('Pegamentos', 22),
#  ('Cepillos y peines', 22),
#  ('Set Relax', 22),
#  ('Guantes', 21),
#  ('Mocasines', 21),
#  ('Joyería Hombre', 21),
#  ('Monitores IPS', 21),
#  ('Fundas para portátil', 21),
#  ('Orquesta y banda', 21),
#  ('Campanas convencionales', 21),
#  ('Hervidoras', 21),
#  ('Exprimidores', 21),
#  ('Cintas de correr', 21),
#  ('Taburetes', 21),
#  ('Sillones', 21),
#  ('Básicos', 21),
#  ('Balanzas', 21),
#  ('Cestas', 21),
#  ('Cestos de ropa', 21),
#  ('Sonajeros y mordedores', 21),
#  ('Barreras para puertas y camas', 21),
#  ...]

# %% [markdown]
# Aqui tenemos un ejemplo parecido al de las Marcas, el objetivo es poner el texto de la Categoria en el Bag of Words de ese producto

# %% [markdown]
# #### Nos guardamos las categorias al igual que las marcas

# %%
subset = data_copy[['id', 'category']]
#subset = subset.groupby('category').apply(lambda x: x['id'].values.tolist()).reset_index(name='col')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     165         mutated = self.mutated
# --> 166         splitter = self._get_splitter(data, axis=axis)
#     167         group_keys = self._get_group_keys()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _get_splitter(self, data, axis)
#     148     def _get_splitter(self, data, axis=0):
# --> 149         comp_ids, _, ngroups = self.group_info
#     150         return get_splitter(data, comp_ids, ngroups, axis=axis)
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in group_info(self)
#     251     def group_info(self):
# --> 252         comp_ids, obs_group_ids = self._get_compressed_labels()
#     253
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _get_compressed_labels(self)
#     267     def _get_compressed_labels(self):
# --> 268         all_labels = [ping.labels for ping in self.groupings]
#     269         if len(all_labels) > 1:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in <listcomp>(.0)
#     267     def _get_compressed_labels(self):
# --> 268         all_labels = [ping.labels for ping in self.groupings]
#     269         if len(all_labels) > 1:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in labels(self)
#     366         if self._labels is None:
# --> 367             self._make_labels()
#     368         return self._labels
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _make_labels(self)
#     391                 labels, uniques = algorithms.factorize(
# --> 392                     self.grouper, sort=self.sort)
#     393                 uniques = Index(uniques, name=self.name)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     612                                            size_hint=size_hint,
# --> 613                                            na_value=na_value)
#     614
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     459     uniques, labels = table.factorize(values, na_sentinel=na_sentinel,
# --> 460                                       na_value=na_value)
#     461
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-29d21c19af86> in <module>
#       1 subset = data_copy[['id', 'category']]
# ----> 2 subset = subset.groupby('category').apply(lambda x: x['id'].values.tolist()).reset_index(name='col')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     699
#     700                 with _group_selection_context(self):
# --> 701                     return self._python_apply_general(f)
#     702
#     703         return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     164     def apply(self, f, data, axis=0):
#     165         mutated = self.mutated
# --> 166         splitter = self._get_splitter(data, axis=axis)
#     167         group_keys = self._get_group_keys()
#     168
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _get_splitter(self, data, axis)
#     147
#     148     def _get_splitter(self, data, axis=0):
# --> 149         comp_ids, _, ngroups = self.group_info
#     150         return get_splitter(data, comp_ids, ngroups, axis=axis)
#     151
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in group_info(self)
#     250     @cache_readonly
#     251     def group_info(self):
# --> 252         comp_ids, obs_group_ids = self._get_compressed_labels()
#     253
#     254         ngroups = len(obs_group_ids)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _get_compressed_labels(self)
#     266
#     267     def _get_compressed_labels(self):
# --> 268         all_labels = [ping.labels for ping in self.groupings]
#     269         if len(all_labels) > 1:
#     270             group_index = get_group_index(all_labels, self.shape,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in <listcomp>(.0)
#     266
#     267     def _get_compressed_labels(self):
# --> 268         all_labels = [ping.labels for ping in self.groupings]
#     269         if len(all_labels) > 1:
#     270             group_index = get_group_index(all_labels, self.shape,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in labels(self)
#     365     def labels(self):
#     366         if self._labels is None:
# --> 367             self._make_labels()
#     368         return self._labels
#     369
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _make_labels(self)
#     390             else:
#     391                 labels, uniques = algorithms.factorize(
# --> 392                     self.grouper, sort=self.sort)
#     393                 uniques = Index(uniques, name=self.name)
#     394             self._labels = labels
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     611                                            na_sentinel=na_sentinel,
#     612                                            size_hint=size_hint,
# --> 613                                            na_value=na_value)
#     614
#     615     if sort and len(uniques) > 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     458     table = hash_klass(size_hint or len(values))
#     459     uniques, labels = table.factorize(values, na_sentinel=na_sentinel,
# --> 460                                       na_value=na_value)
#     461
#     462     labels = ensure_platform_int(labels)
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
subset
# Out:
#                      id  \
# 0         1060651400131
# 1         1060651400180
# 2         1051056400107
# 3         1019350401147
# 4         1019353400229
# 5         1019353400245
# 6         1052353400071
# 7         1087557400030
# 8         1019350401022
# 9         1051053400118
# 10        1051053400142
# 11        1052353400105
# 12        1052357400051
# 13        1051053400134
# 14        1051053400175
# 15        1035151400732
# 16        1019350401006
# 17        1035151400849
# 18        1084952400137
# 19        1035151400831
# 20        1051053400167
# 21        1035151400856
# 22        1035152400095
# 23        1084950400501
# 24        8434627112709
# 25        8434086164967
# 26        8434086164974
# 27         767336160630
# 28        1097956231167
# 29        8434519247267
# ...                 ...
# 126807  019000200707867
# 126808  019000200707891
# 126809  019000200708071
# 126810  019000200708162
# 126811  019000200708204
# 126812  019000200708220
# 126813  019000200708246
# 126814  019000200708261
# 126815  019000200708287
# 126816  019000200708295
# 126817  019000200708303
# 126818  019000200708329
# 126819  019000200708345
# 126820  019000200708402
# 126821  019000200708477
# 126822  019000200708485
# 126823  019000200708501
# 126824  019000200708527
# 126825  019000200708642
# 126826  019000200708691
# 126827  019000200708725
# 126828  019000200708733
# 126829  019000200708774
# 126830  019000200708915
# 126831  019000200708923
# 126832  019000200709053
# 126833  019000200709145
# 126834  019000200709194
# 126835  019000200709251
# 126836  019000200709269
#
#                                                                                               category
# 0                                                                               [Moda, Mujer, Abrigos]
# 1                                                                               [Moda, Mujer, Abrigos]
# 2                                                                               [Moda, Mujer, Abrigos]
# 3                                                                               [Moda, Mujer, Abrigos]
# 4                                                                               [Moda, Mujer, Abrigos]
# 5                                                                               [Moda, Mujer, Abrigos]
# 6                                                                               [Moda, Mujer, Abrigos]
# 7                                                                               [Moda, Mujer, Abrigos]
# 8                                                                               [Moda, Mujer, Abrigos]
# 9                                                                               [Moda, Mujer, Abrigos]
# 10                                                                              [Moda, Mujer, Abrigos]
# 11                                                                              [Moda, Mujer, Abrigos]
# 12                                                                              [Moda, Mujer, Abrigos]
# 13                                                                              [Moda, Mujer, Abrigos]
# 14                                                                              [Moda, Mujer, Abrigos]
# 15                                                                              [Moda, Mujer, Abrigos]
# 16                                                                              [Moda, Mujer, Abrigos]
# 17                                                                              [Moda, Mujer, Abrigos]
# 18                                                                              [Moda, Mujer, Abrigos]
# 19                                                                              [Moda, Mujer, Abrigos]
# 20                                                                              [Moda, Mujer, Abrigos]
# 21                                                                              [Moda, Mujer, Abrigos]
# 22                                                                              [Moda, Mujer, Abrigos]
# 23                                                                              [Moda, Mujer, Abrigos]
# 24                                                                              [Moda, Mujer, Abrigos]
# 25                                                                              [Moda, Mujer, Abrigos]
# 26                                                                              [Moda, Mujer, Abrigos]
# 27                                                                              [Moda, Mujer, Abrigos]
# 28                                                                              [Moda, Mujer, Abrigos]
# 29                                                                              [Moda, Mujer, Abrigos]
# ...                                                                                                ...
# 126807                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126808                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126809                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126810                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126811                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126812                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126813                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126814                    [BriCor, Puertas y ventanas, Puertas de Entrada, Puertas Blindadas interior]
# 126815                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126816                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126817                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126818                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126819                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126820                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126821                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126822  [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Otros acabados sintéticos]
# 126823  [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Otros acabados sintéticos]
# 126824                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126825                    [BriCor, Puertas y ventanas, Puertas de Entrada, Puertas Blindadas interior]
# 126826                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126827                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126828                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126829                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126830                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126831                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126832                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126833                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126834                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
# 126835  [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Otros acabados sintéticos]
# 126836                   [BriCor, Puertas y ventanas, Puertas Interiores Sintéticas, Puertas Melamina]
#
# [126837 rows x 2 columns]

# %%
subset.to_csv('Categorias_20190308.csv', sep = ';', index=False, encoding = 'UTF-8')

# %% [markdown]
# ### Price

# %% [markdown]
# Se ha observado que el precio siempre esta en EUR y la cantidad no nos aporta ninguna info importante en este Proyecto, dados los datos que vamos a tener del cliente

# %%
data = data.drop(['price'], axis = 1)
data.head()
# Out:
#    Unnamed: 0                          brand                      category  \
# 0           0  Woman Limited El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']
# 1           1  Woman Limited El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']
# 2           2          Woman El Corte Inglés  ['Moda', 'Mujer', 'Abrigos']
# 3           3                        Lloyd's  ['Moda', 'Mujer', 'Abrigos']
# 4           4                        Lloyd's  ['Moda', 'Mujer', 'Abrigos']
#
#               id  \
# 0  1060651400131
# 1  1060651400180
# 2  1051056400107
# 3  1019350401147
# 4  1019353400229
#
#                                                                                        image  \
# 0  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00160651400131____1__516x640.jpg
# 1  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/06/00160651400180____1__516x640.jpg
# 2  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00151056400115____1__516x640.jpg
# 3  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00119350401147____3__516x640.jpg
# 4  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00119353400237____2__516x640.jpg
#
#                                                        name
# 0                     Abrigo masculino con textura de mujer
# 1             Abrigo doble faz de mujer con cinturón a tono
# 2   Abrigo largo de antelina de mujer Woman El Corte Inglés
# 3  Chaqueta térmica de mujer Lloyds con efecto cortavientos
# 4            Parka 100% algodón de mujer Lloyds con capucha

# %%
data.loc[70000]
# Out:
# Unnamed: 0                                                                                        70000
# brand                                                                                   El Corte Inglés
# category                                        ['Hogar', 'Menaje de mesa', 'Café y té', 'Tazas de té']
# id                                                                                      001007227340655
# image         http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201803/12/00107227340655____1__640x640.jpg
# name                                                          Set de 2 tazas de té Buga El Corte Inglés
# Name: 70000, dtype: object

# %% [markdown]
# ## Imagenes

# %%
images = data[['id', 'image']]
images.head()
# Out:
#               id  \
# 0  1060651400131
# 1  1060651400180
# 2  1051056400107
# 3  1019350401147
# 4  1019353400229
#
#                                                                                        image
# 0  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00160651400131____1__516x640.jpg
# 1  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/06/00160651400180____1__516x640.jpg
# 2  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00151056400115____1__516x640.jpg
# 3  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00119350401147____3__516x640.jpg
# 4  http://sgfm.elcorteingles.es/SGFM/dctm/MEDIA03/201902/07/00119353400237____2__516x640.jpg

# %%
images.to_csv('Imagenes_20190308.csv', sep = ';', index=False, encoding = 'UTF-8')

# %% [markdown]
# ---
